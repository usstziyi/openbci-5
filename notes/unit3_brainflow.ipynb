# %% [markdown]
# BrainFlow 文档说明 BrainFlow 主要有三个模块：
# |模块|功能|详情|
# |--|--|--|
# |BoardShim|负责采集数据|负责与 OpenBCI 板卡交互，采集数据并将其转换为 BrainFlow 格式|
# |DataFilter|负责处理数据|负责滤波、频谱分析、文件读写、降采样、小波变换等静态工具函数|
# |MLModel|负责机器学习|负责训练和使用机器学习模型，如分类、回归等|
