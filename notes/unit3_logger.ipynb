# %% [markdown]
# ```Text
# LEVEL_TRACE      # 最详细
# LEVEL_DEBUG
# LEVEL_INFO
# LEVEL_WARN
# LEVEL_ERROR
# LEVEL_CRITICAL
# LEVEL_OFF        # 关闭
# ```

# %%
DataFilter.enable_data_logger()
DataFilter.enable_dev_data_logger()

DataFilter.disable_data_logger() # 关闭日志
BoardShim.set_log_level(LogLevels.LEVEL_OFF) # 关闭日志

DataFilter.set_log_level(LogLevels.LEVEL_ERROR)
DataFilter.set_log_file("brainflow_data.log")

DataFilter.log_message(LogLevels.LEVEL_INFO, "data filter message")
